# %%
# !pip install yfinance investpy

# %%
import pandas as pd
import yfinance as yf
import investpy as inv

# %%
br_tickers = inv.stocks.get_stocks(country='brazil')

# %%
br_tickers.count()
# Out:
# country      749
# name         749
# full_name    749
# isin         749
# currency     749
# symbol       749
# dtype: int64

# %%
wallet = []
for ticker in br_tickers['symbol']:
  if len(ticker) <= 5: wallet.append(f'{ticker}.SA')

# %%
wallet[0]
# Out:
# 'ABCB4.SA'

# %%
dt_test = yf.download('TAEE11.SA', start='2023-12-28', end='2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dt_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1 entries, 2023-12-28 to 2023-12-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1 non-null      float64
#  1   High       1 non-null      float64
#  2   Low        1 non-null      float64
#  3   Close      1 non-null      float64
#  4   Adj Close  1 non-null      float64
#  5   Volume     1 non-null      int64
# dtypes: float64(5), int64(1)
# memory usage: 56.0 bytes

# %%
dt_test
# Out:
#             Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-12-28  38.0  38.459999  37.900002  38.380001  38.380001  1739100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dt = yf.download(wallet, start='1900-01-01', end='2023-12-31')['Adj Close'] # Adj Close = Fechamento ajustado/arredondado
# Out:
# [*********************100%%**********************]  747 of 747 completed
# ERROR:yfinance:
# 163 Failed downloads:
# ...

# %%
dt.head(2)
# Out:
#                      AALL34.SA  AALR3.SA  AAPL34.SA  ABBV34.SA  ABCB10.SA  \
# Date
# 2021-01-04 00:00:00  80.099998     11.13  33.687164  31.376738        NaN
# 2021-01-05 00:00:00  81.589996     10.79  33.991894  31.376738        NaN
# 2021-01-06 00:00:00  82.250000     10.63  33.112110  32.073006        NaN
#
#                       ABCB4.SA  ABCP11.SA   ABEV3.SA  ABTT34.SA    ACNB34.SA  \
# Date
# 2021-01-04 00:00:00  12.737449  63.728916  13.386032  45.988304  1298.143433
# 2021-01-05 00:00:00  12.556610  63.780334  13.671393  45.988304  1317.360596
# 2021-01-06 00:00:00  12.698137  63.377571  13.948107  46.803452  1355.290283
#
#                      ...  XPCM11.SA  XPHT11.SA  XPHT12.SA  XPIN11.SA  \
# Date                 ...
# 2021-01-04 00:00:00  ...  40.770489  77.614212        NaN  97.330368
# 2021-01-05 00:00:00  ...  41.190800  77.614212        NaN  98.491638
# 2021-01-06 00:00:00  ...  41.266457  76.559448        NaN  98.115700
#
# ...

# %%
dt.count()
# Out:
# AALL34.SA    247
# AALR3.SA     247
# AAPL34.SA    247
# ABBV34.SA    247
# ABCB10.SA      0
#             ...
# XPOM11.SA      0
# XRXB34.SA    247
# XTED11.SA      0
# YCHY11.SA    247
# YDUQ3.SA     247
# Length: 747, dtype: int64

# %%
# df.to_csv()
