# %%
# !pip install SQLAlchemy pandas keras pymysql cryptography scikit-learn numpy matplotlib tensorflow
# Out:
# Requirement already satisfied: SQLAlchemy in /opt/conda/lib/python3.11/site-packages (2.0.22)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: keras in /opt/conda/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: pymysql in /opt/conda/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.11/site-packages (41.0.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.26.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.15.0.post1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.4)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography) (1.16.0)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography) (2.21)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# !pip install --upgrade tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.15.0.post1)
# Requirement already satisfied: keras in /opt/conda/lib/python3.11/site-packages (2.15.0)
# Collecting keras
#   Using cached keras-3.0.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.26.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# importing libs for ml model
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler

from sqlalchemy import create_engine
from pyspark.sql import SparkSession
# Out:
# 2024-01-17 23:12:03.459955: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-17 23:12:03.500947: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-17 23:12:03.700347: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-17 23:12:03.700392: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-17 23:12:03.737260: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-17 23:12:03.815584: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-17 23:12:03.816832: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-17 23:12:04.716643: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# connecting with mysql
MYSQL_USER = os.environ.get('MYSQL_USER', 'root')
MYSQL_PASSWORD = os.environ.get('MYSQL_PASSWORD', 'secret')
MYSQL_DATABASE = os.environ.get('MYSQL_DATABASE', 'mydatabase')
MYSQL_DC_HOSTNAME = os.environ.get('MYSQL_DC_HOSTNAME', 'bigdata-mysql')

URL_CONNECT = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_DC_HOSTNAME}:3306/{MYSQL_DATABASE}'

MYSQL_CONNECTION = create_engine(URL_CONNECT)

# %%
# --------------------------- Test

# %%
# query = "SELECT * FROM stock_data limit 1439833;"
# df = pd.read_sql_query(query, con=MYSQL_CONNECTION)
# df

# %%
# -------------------------- End Test

# %%
#
# Configuring Spark to execute queries
#

mysql_connector_path = "./mysql-connector-j-8.1.0.jar"
os.environ['PYSPARK_SUBMIT_ARGS'] = f'--jars {mysql_connector_path} --master spark://bigdata-spark:7077 pyspark-shell'

mysql_url = "jdbc:mysql://bigdata-mysql:3306/mydatabase"
mysql_properties = {
    "driver": "com.mysql.cj.jdbc.Driver",
    "user": "user",
    "password": "secret"
}

# %%
#
# Spark - Creating session
#
spark = SparkSession.builder.appName("MySQLDataRead").getOrCreate()
# Out:
# 24/01/17 23:12:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Reading data by MySQL and converting to a spark dataframe
base = spark.read \
    .format("jdbc") \
    .option("url", mysql_url) \
    .option("dbtable", "stock_data") \
    .option("user", mysql_properties["user"]) \
    .option("password", mysql_properties["password"]) \
    .option("driver", mysql_properties["driver"]) \
    .load()

# Show the spark dataframe
base.show()

# Finish this spark session
# spark.stop()
# Out:
# +----------+------------------+-------+------+------------------+------------------+------------------+-------+---------+------------+
# |      Date|              Open|Country|Ticker|              High|               Low|             Close| Volume|Dividends|Stock Splits|
# +----------+------------------+-------+------+------------------+------------------+------------------+-------+---------+------------+
# |2007-09-26| 4.605397613267905| brazil| ABCB4| 4.684622764587402| 4.515838979347431| 4.684622764587402|  72665|      0.0|         0.0|
# |2007-09-27| 4.605397613267905| brazil| ABCB4| 4.684622764587402| 4.515838979347431| 4.684622764587402|  72665|      0.0|         0.0|
# |2007-09-28| 4.753513813018799| brazil| ABCB4|   4.9601887922053| 4.753513813018799| 4.753513813018799| 442102|      0.0|         0.0|
# |2007-10-01| 4.684622519848403| brazil| ABCB4| 4.942965817868213| 4.684622519848403| 4.805182933807373| 318368|      0.0|         0.0|
# |2007-10-02| 4.801737099270801| brazil| ABCB4| 4.818960010742479|4.6501758352623215|  4.79829216003418|  42105|      0.0|         0.0|
# |2007-10-03| 4.801737099270801| brazil| ABCB4| 4.818960010742479|4.6501758352623215|  4.79829216003418|  42105|      0.0|         0.0|
# |2007-10-04| 4.660509819896823| brazil| ABCB4| 4.781069755554199| 4.660509819896823| 4.781069755554199|  42376|      0.0|         0.0|
# |2007-10-05| 4.650176994824136| brazil| ABCB4| 4.787959874777053| 4.650176994824136| 4.784515380859375|  60033|      0.0|         0.0|
# |2007-10-08| 4.839628495783543| brazil| ABCB4| 4.960188903001983| 4.805182665149703|4.9257426261901855| 259013|      0.0|         0.0|
# |2007-10-09| 4.839628495783543| brazil| ABCB4| 4.960188903001983| 4.805182665149703|4.9257426261901855| 259013|      0.0|         0.0|
# |2007-10-10|   4.9085196243896| brazil| ABCB4| 5.029079126169276|   4.9085196243896| 4.915408611297607|1344644|      0.0|         0.0|
# |2007-10-11|4.9567438280288245| brazil| ABCB4| 5.025635487420651| 4.908520023396902|  4.99463415145874| 177656|      0.0|         0.0|
# |2007-10-15| 5.097970302579201| brazil| ABCB4| 5.201307773590088| 5.032523594547933| 5.201307773590088| 415481|      0.0|         0.0|
# |2007-10-16|5.0979708015065235| brazil| ABCB4| 5.201308282630825|5.0325240870701275| 5.184085369110107| 416024|      0.0|         0.0|
# |2007-10-17| 5.097970302579201| brazil| ABCB4| 5.225419671688147| 5.097970302579201| 5.201307773590088|2011805|      0.0|         0.0|
# |2007-10-18| 5.097970302579201| brazil| ABCB4| 5.225419671688147| 5.097970302579201| 5.201307773590088|2011805|      0.0|         0.0|
# |2007-10-19| 5.201307594049082| brazil| ABCB4|  5.30464506149292| 5.166861771567802|  5.30464506149292| 322986|      0.0|         0.0|
# |2007-10-22| 5.115193154783769| brazil| ABCB4| 5.270198913315245| 5.115193154783769| 5.235753536224365|1033474|      0.0|         0.0|
# |2007-10-23| 5.115193154783769| brazil| ABCB4| 5.270198913315245| 5.115193154783769| 5.235753536224365|1033474|      0.0|         0.0|
# |2007-10-24|5.2874237367871135| brazil| ABCB4|5.2874237367871135| 5.149640405518977| 5.263311386108398| 143836|      0.0|         0.0|
# +----------+------------------+-------+------+------------------+------------------+------------------+-------+---------+------------+
# only showing top 20 rows

# %%
# -------------------------- Model

# %%
# Assuming that 'base' is already loaded using Spark DataFrame
# You can replace the code below with your Spark DataFrame operations

# Assuming 'Open' column contains the stock prices
base_treinamento = base.select('Open').toPandas().dropna()

# %%
# Feature scaling
normalizador = MinMaxScaler(feature_range=(0, 1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
# Creating input sequences and labels
previsores = []
preco_real = []

for i in range(90, len(base_treinamento_normalizada)):
    previsores.append(base_treinamento_normalizada[i-90:i, 0])
    preco_real.append(base_treinamento_normalizada[i, 0])

previsores, preco_real = np.array(previsores), np.array(preco_real)
previsores = np.reshape(previsores, (previsores.shape[0], previsores.shape[1], 1))

# %%
# Building the LSTM model
regressor = Sequential()
regressor.add(LSTM(units=100, return_sequences=True, input_shape=(previsores.shape[1], 1)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units=1, activation='linear'))

# %%
regressor.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
# regressor.fit(previsores, preco_real, epochs=100, batch_size=32)

# %%
# Specify batch size
batch_size = 32

# Calculate the number of batches
num_batches = len(preco_real) // batch_size
num_batches = 2

# Training the model in batches
epochs = 100  # You can adjust the number of epochs
counter = 0
for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    # Extract batch data
    batch_previsores = previsores[start_idx:end_idx]
    batch_preco_real = preco_real[start_idx:end_idx]

    # Train the model on the current batch
    regressor.fit(batch_previsores, batch_preco_real, epochs=epochs, batch_size=batch_size)

    counter+=1

    print(f'\n\n\nCounter = {counter}')
    print(f'\n\n\nNum_batches = {num_batches}')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0034 - mean_absolute_error: 0.0583
# Epoch 2/100
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3872e-04 - mean_absolute_error: 0.0099
# Epoch 3/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.0201e-04 - mean_absolute_error: 0.0087
# Epoch 4/100
# 1/1 [==============================] - 0s 70ms/step - loss: 8.4791e-05 - mean_absolute_error: 0.0067
# Epoch 5/100
# 1/1 [==============================] - 0s 73ms/step - loss: 7.1947e-05 - mean_absolute_error: 0.0065
# Epoch 6/100
# 1/1 [==============================] - 0s 74ms/step - loss: 6.9289e-05 - mean_absolute_error: 0.0066
# Epoch 7/100
# 1/1 [==============================] - 0s 80ms/step - loss: 5.2880e-05 - mean_absolute_error: 0.0055
# Epoch 8/100
# 1/1 [==============================] - 0s 69ms/step - loss: 7.3410e-05 - mean_absolute_error: 0.0072
# Epoch 9/100
# 1/1 [==============================] - 0s 91ms/step - loss: 5.6710e-05 - mean_absolute_error: 0.0061
# Epoch 10/100
# 1/1 [==============================] - 0s 74ms/step - loss: 6.3753e-05 - mean_absolute_error: 0.0063
# Epoch 11/100
# 1/1 [==============================] - 0s 115ms/step - loss: 4.8872e-05 - mean_absolute_error: 0.0054
# Epoch 12/100
# 1/1 [==============================] - 0s 98ms/step - loss: 3.8277e-05 - mean_absolute_error: 0.0048
# Epoch 13/100
# 1/1 [==============================] - 0s 92ms/step - loss: 5.6303e-05 - mean_absolute_error: 0.0062
# Epoch 14/100
# 1/1 [==============================] - 0s 85ms/step - loss: 4.1488e-05 - mean_absolute_error: 0.0055
# Epoch 15/100
# 1/1 [==============================] - 0s 74ms/step - loss: 5.8565e-05 - mean_absolute_error: 0.0058
# Epoch 16/100
# 1/1 [==============================] - 0s 69ms/step - loss: 5.9450e-05 - mean_absolute_error: 0.0064
# Epoch 17/100
# 1/1 [==============================] - 0s 76ms/step - loss: 4.5014e-05 - mean_absolute_error: 0.0054
# Epoch 18/100
# 1/1 [==============================] - 0s 72ms/step - loss: 7.0981e-05 - mean_absolute_error: 0.0072
# Epoch 19/100
# 1/1 [==============================] - 0s 72ms/step - loss: 1.0955e-04 - mean_absolute_error: 0.0092
# Epoch 20/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.9056e-04 - mean_absolute_error: 0.0117
# Epoch 21/100
# 1/1 [==============================] - 0s 72ms/step - loss: 2.8957e-04 - mean_absolute_error: 0.0165
# Epoch 22/100
# 1/1 [==============================] - 0s 70ms/step - loss: 2.7575e-04 - mean_absolute_error: 0.0148
# Epoch 23/100
# 1/1 [==============================] - 0s 74ms/step - loss: 2.0484e-04 - mean_absolute_error: 0.0136
# Epoch 24/100
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3853e-04 - mean_absolute_error: 0.0102
# Epoch 25/100
# 1/1 [==============================] - 0s 70ms/step - loss: 7.8148e-05 - mean_absolute_error: 0.0076
# Epoch 26/100
# 1/1 [==============================] - 0s 72ms/step - loss: 7.6027e-05 - mean_absolute_error: 0.0072
# Epoch 27/100
# 1/1 [==============================] - 0s 70ms/step - loss: 1.4684e-04 - mean_absolute_error: 0.0106
# Epoch 28/100
# 1/1 [==============================] - 0s 69ms/step - loss: 9.2267e-05 - mean_absolute_error: 0.0084
# Epoch 29/100
# 1/1 [==============================] - 0s 71ms/step - loss: 3.5149e-05 - mean_absolute_error: 0.0049
# Epoch 30/100
# 1/1 [==============================] - 0s 73ms/step - loss: 2.8272e-05 - mean_absolute_error: 0.0040
# Epoch 31/100
# 1/1 [==============================] - 0s 92ms/step - loss: 3.5766e-05 - mean_absolute_error: 0.0049
# Epoch 32/100
# 1/1 [==============================] - 0s 74ms/step - loss: 4.5075e-05 - mean_absolute_error: 0.0055
# Epoch 33/100
# 1/1 [==============================] - 0s 70ms/step - loss: 3.1483e-05 - mean_absolute_error: 0.0044
# Epoch 34/100
# 1/1 [==============================] - 0s 78ms/step - loss: 7.2507e-05 - mean_absolute_error: 0.0067
# Epoch 35/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.7062e-04 - mean_absolute_error: 0.0122
# Epoch 36/100
# 1/1 [==============================] - 0s 74ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0120
# Epoch 37/100
# 1/1 [==============================] - 0s 127ms/step - loss: 2.2775e-04 - mean_absolute_error: 0.0142
# Epoch 38/100
# 1/1 [==============================] - 0s 159ms/step - loss: 1.5715e-04 - mean_absolute_error: 0.0110
# Epoch 39/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1247e-04 - mean_absolute_error: 0.0096
# Epoch 40/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0769e-04 - mean_absolute_error: 0.0081
# Epoch 41/100
# 1/1 [==============================] - 0s 73ms/step - loss: 5.1900e-05 - mean_absolute_error: 0.0064
# Epoch 42/100
# 1/1 [==============================] - 0s 70ms/step - loss: 6.1774e-05 - mean_absolute_error: 0.0067
# Epoch 43/100
# 1/1 [==============================] - 0s 70ms/step - loss: 6.7670e-05 - mean_absolute_error: 0.0067
# Epoch 44/100
# 1/1 [==============================] - 0s 70ms/step - loss: 5.0555e-05 - mean_absolute_error: 0.0061
# Epoch 45/100
# 1/1 [==============================] - 0s 76ms/step - loss: 6.8371e-05 - mean_absolute_error: 0.0069
# Epoch 46/100
# 1/1 [==============================] - 0s 84ms/step - loss: 7.0640e-05 - mean_absolute_error: 0.0070
# Epoch 47/100
# 1/1 [==============================] - 0s 73ms/step - loss: 3.9401e-05 - mean_absolute_error: 0.0049
# Epoch 48/100
# 1/1 [==============================] - 0s 71ms/step - loss: 2.6852e-05 - mean_absolute_error: 0.0042
# Epoch 49/100
# 1/1 [==============================] - 0s 69ms/step - loss: 4.2553e-05 - mean_absolute_error: 0.0058
# Epoch 50/100
# 1/1 [==============================] - 0s 66ms/step - loss: 7.8739e-05 - mean_absolute_error: 0.0074
# Epoch 51/100
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3554e-04 - mean_absolute_error: 0.0109
# Epoch 52/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.9969e-04 - mean_absolute_error: 0.0128
# Epoch 53/100
# 1/1 [==============================] - 0s 70ms/step - loss: 3.1888e-04 - mean_absolute_error: 0.0171
# Epoch 54/100
# 1/1 [==============================] - 0s 70ms/step - loss: 2.7299e-04 - mean_absolute_error: 0.0150
# Epoch 55/100
# 1/1 [==============================] - 0s 69ms/step - loss: 1.9683e-04 - mean_absolute_error: 0.0134
# Epoch 56/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.1408e-04 - mean_absolute_error: 0.0094
# Epoch 57/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1006e-04 - mean_absolute_error: 0.0093
# Epoch 58/100
# 1/1 [==============================] - 0s 73ms/step - loss: 7.9670e-05 - mean_absolute_error: 0.0076
# Epoch 59/100
# 1/1 [==============================] - 0s 80ms/step - loss: 8.3701e-05 - mean_absolute_error: 0.0083
# Epoch 60/100
# 1/1 [==============================] - 0s 79ms/step - loss: 7.8310e-05 - mean_absolute_error: 0.0081
# Epoch 61/100
# 1/1 [==============================] - 0s 71ms/step - loss: 6.6021e-05 - mean_absolute_error: 0.0070
# Epoch 62/100
# 1/1 [==============================] - 0s 74ms/step - loss: 5.4786e-05 - mean_absolute_error: 0.0057
# Epoch 63/100
# 1/1 [==============================] - 0s 71ms/step - loss: 4.5515e-05 - mean_absolute_error: 0.0056
# Epoch 64/100
# 1/1 [==============================] - 0s 71ms/step - loss: 4.0340e-05 - mean_absolute_error: 0.0051
# Epoch 65/100
# 1/1 [==============================] - 0s 69ms/step - loss: 5.2984e-05 - mean_absolute_error: 0.0061
# Epoch 66/100
# 1/1 [==============================] - 0s 68ms/step - loss: 4.7865e-05 - mean_absolute_error: 0.0054
# Epoch 67/100
# 1/1 [==============================] - 0s 71ms/step - loss: 4.9519e-05 - mean_absolute_error: 0.0058
# Epoch 68/100
# 1/1 [==============================] - 0s 70ms/step - loss: 4.1810e-05 - mean_absolute_error: 0.0052
# Epoch 69/100
# 1/1 [==============================] - 0s 65ms/step - loss: 6.1987e-05 - mean_absolute_error: 0.0068
# Epoch 70/100
# 1/1 [==============================] - 0s 69ms/step - loss: 9.5217e-05 - mean_absolute_error: 0.0082
# Epoch 71/100
# 1/1 [==============================] - 0s 70ms/step - loss: 9.5682e-05 - mean_absolute_error: 0.0092
# Epoch 72/100
# 1/1 [==============================] - 0s 85ms/step - loss: 1.0992e-04 - mean_absolute_error: 0.0088
# Epoch 73/100
# 1/1 [==============================] - 0s 76ms/step - loss: 7.9311e-05 - mean_absolute_error: 0.0078
# Epoch 74/100
# 1/1 [==============================] - 0s 68ms/step - loss: 6.3695e-05 - mean_absolute_error: 0.0062
# Epoch 75/100
# 1/1 [==============================] - 0s 70ms/step - loss: 5.1488e-05 - mean_absolute_error: 0.0062
# Epoch 76/100
# 1/1 [==============================] - 0s 72ms/step - loss: 5.7536e-05 - mean_absolute_error: 0.0060
# Epoch 77/100
# 1/1 [==============================] - 0s 72ms/step - loss: 6.5471e-05 - mean_absolute_error: 0.0068
# Epoch 78/100
# 1/1 [==============================] - 0s 72ms/step - loss: 6.8070e-05 - mean_absolute_error: 0.0069
# Epoch 79/100
# 1/1 [==============================] - 0s 75ms/step - loss: 9.1432e-05 - mean_absolute_error: 0.0087
# Epoch 80/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.3608e-04 - mean_absolute_error: 0.0103
# Epoch 81/100
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5134e-04 - mean_absolute_error: 0.0115
# Epoch 82/100
# 1/1 [==============================] - 0s 84ms/step - loss: 1.0444e-04 - mean_absolute_error: 0.0085
# Epoch 83/100
# 1/1 [==============================] - 0s 87ms/step - loss: 8.9212e-05 - mean_absolute_error: 0.0083
# Epoch 84/100
# 1/1 [==============================] - 0s 72ms/step - loss: 7.4102e-05 - mean_absolute_error: 0.0070
# Epoch 85/100
# 1/1 [==============================] - 0s 67ms/step - loss: 7.2195e-05 - mean_absolute_error: 0.0070
# Epoch 86/100
# 1/1 [==============================] - 0s 72ms/step - loss: 7.5002e-05 - mean_absolute_error: 0.0075
# Epoch 87/100
# 1/1 [==============================] - 0s 69ms/step - loss: 5.8838e-05 - mean_absolute_error: 0.0067
# Epoch 88/100
# 1/1 [==============================] - 0s 76ms/step - loss: 5.3661e-05 - mean_absolute_error: 0.0061
# Epoch 89/100
# 1/1 [==============================] - 0s 73ms/step - loss: 6.7079e-05 - mean_absolute_error: 0.0070
# Epoch 90/100
# 1/1 [==============================] - 0s 75ms/step - loss: 7.0507e-05 - mean_absolute_error: 0.0073
# Epoch 91/100
# 1/1 [==============================] - 0s 70ms/step - loss: 7.6573e-05 - mean_absolute_error: 0.0073
# Epoch 92/100
# 1/1 [==============================] - 0s 72ms/step - loss: 6.7539e-05 - mean_absolute_error: 0.0068
# Epoch 93/100
# 1/1 [==============================] - 0s 77ms/step - loss: 9.2806e-05 - mean_absolute_error: 0.0086
# Epoch 94/100
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1964e-04 - mean_absolute_error: 0.0095
# Epoch 95/100
# 1/1 [==============================] - 0s 90ms/step - loss: 1.4984e-04 - mean_absolute_error: 0.0116
# Epoch 96/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3607e-04 - mean_absolute_error: 0.0100
# Epoch 97/100
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3021e-04 - mean_absolute_error: 0.0101
# Epoch 98/100
# 1/1 [==============================] - 0s 69ms/step - loss: 1.1276e-04 - mean_absolute_error: 0.0094
# Epoch 99/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1271e-04 - mean_absolute_error: 0.0099
# Epoch 100/100
# 1/1 [==============================] - 0s 76ms/step - loss: 6.8701e-05 - mean_absolute_error: 0.0070
#
#
#
# Counter = 1
#
#
#
# Num_batches = 2
# Epoch 1/100
# 1/1 [==============================] - 0s 68ms/step - loss: 4.7435e-05 - mean_absolute_error: 0.0055
# Epoch 2/100
# 1/1 [==============================] - 0s 69ms/step - loss: 2.6614e-05 - mean_absolute_error: 0.0043
# Epoch 3/100
# 1/1 [==============================] - 0s 71ms/step - loss: 3.2139e-05 - mean_absolute_error: 0.0047
# Epoch 4/100
# 1/1 [==============================] - 0s 71ms/step - loss: 3.1719e-05 - mean_absolute_error: 0.0047
# Epoch 5/100
# 1/1 [==============================] - 0s 77ms/step - loss: 4.3677e-05 - mean_absolute_error: 0.0054
# Epoch 6/100
# 1/1 [==============================] - 0s 69ms/step - loss: 3.0768e-05 - mean_absolute_error: 0.0047
# Epoch 7/100
# 1/1 [==============================] - 0s 69ms/step - loss: 5.0678e-05 - mean_absolute_error: 0.0058
# Epoch 8/100
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0382e-04 - mean_absolute_error: 0.0094
# Epoch 9/100
# 1/1 [==============================] - 0s 70ms/step - loss: 9.2573e-05 - mean_absolute_error: 0.0086
# Epoch 10/100
# 1/1 [==============================] - 0s 72ms/step - loss: 7.5112e-05 - mean_absolute_error: 0.0080
# Epoch 11/100
# 1/1 [==============================] - 0s 73ms/step - loss: 9.1275e-05 - mean_absolute_error: 0.0083
# Epoch 12/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3693e-04 - mean_absolute_error: 0.0109
# Epoch 13/100
# 1/1 [==============================] - 0s 68ms/step - loss: 1.1419e-04 - mean_absolute_error: 0.0097
# Epoch 14/100
# 1/1 [==============================] - 0s 77ms/step - loss: 1.1112e-04 - mean_absolute_error: 0.0094
# Epoch 15/100
# 1/1 [==============================] - 0s 143ms/step - loss: 8.0129e-05 - mean_absolute_error: 0.0078
# Epoch 16/100
# 1/1 [==============================] - 0s 73ms/step - loss: 4.8556e-05 - mean_absolute_error: 0.0059
# Epoch 17/100
# 1/1 [==============================] - 0s 88ms/step - loss: 3.7558e-05 - mean_absolute_error: 0.0052
# Epoch 18/100
# 1/1 [==============================] - 0s 72ms/step - loss: 4.5882e-05 - mean_absolute_error: 0.0052
# Epoch 19/100
# 1/1 [==============================] - 0s 74ms/step - loss: 3.8752e-05 - mean_absolute_error: 0.0053
# Epoch 20/100
# 1/1 [==============================] - 0s 73ms/step - loss: 2.3221e-05 - mean_absolute_error: 0.0040
# Epoch 21/100
# 1/1 [==============================] - 0s 74ms/step - loss: 3.8199e-05 - mean_absolute_error: 0.0051
# Epoch 22/100
# 1/1 [==============================] - 0s 72ms/step - loss: 8.5370e-05 - mean_absolute_error: 0.0081
# Epoch 23/100
# 1/1 [==============================] - 0s 75ms/step - loss: 9.3326e-05 - mean_absolute_error: 0.0084
# Epoch 24/100
# 1/1 [==============================] - 0s 75ms/step - loss: 8.3228e-05 - mean_absolute_error: 0.0085
# Epoch 25/100
# 1/1 [==============================] - 0s 106ms/step - loss: 1.0762e-04 - mean_absolute_error: 0.0094
# Epoch 26/100
# 1/1 [==============================] - 0s 77ms/step - loss: 9.7988e-05 - mean_absolute_error: 0.0090
# Epoch 27/100
# 1/1 [==============================] - 0s 78ms/step - loss: 6.3442e-05 - mean_absolute_error: 0.0069
# Epoch 28/100
# 1/1 [==============================] - 0s 77ms/step - loss: 7.8301e-05 - mean_absolute_error: 0.0069
# Epoch 29/100
# 1/1 [==============================] - 0s 74ms/step - loss: 5.5165e-05 - mean_absolute_error: 0.0060
# Epoch 30/100
# 1/1 [==============================] - 0s 74ms/step - loss: 3.8634e-05 - mean_absolute_error: 0.0051
# Epoch 31/100
# 1/1 [==============================] - 0s 79ms/step - loss: 3.7933e-05 - mean_absolute_error: 0.0049
# Epoch 32/100
# 1/1 [==============================] - 0s 71ms/step - loss: 3.9509e-05 - mean_absolute_error: 0.0052
# Epoch 33/100
# 1/1 [==============================] - 0s 73ms/step - loss: 3.7279e-05 - mean_absolute_error: 0.0049
# Epoch 34/100
# 1/1 [==============================] - 0s 74ms/step - loss: 5.0876e-05 - mean_absolute_error: 0.0064
# Epoch 35/100
# 1/1 [==============================] - 0s 78ms/step - loss: 1.1642e-04 - mean_absolute_error: 0.0098
# Epoch 36/100
# 1/1 [==============================] - 0s 72ms/step - loss: 1.8300e-04 - mean_absolute_error: 0.0130
# Epoch 37/100
# 1/1 [==============================] - 0s 72ms/step - loss: 1.6142e-04 - mean_absolute_error: 0.0117
# Epoch 38/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.1640e-04 - mean_absolute_error: 0.0103
# Epoch 39/100
# 1/1 [==============================] - 0s 78ms/step - loss: 6.2983e-05 - mean_absolute_error: 0.0067
# Epoch 40/100
# 1/1 [==============================] - 0s 75ms/step - loss: 4.6613e-05 - mean_absolute_error: 0.0057
# Epoch 41/100
# 1/1 [==============================] - 0s 78ms/step - loss: 4.2454e-05 - mean_absolute_error: 0.0053
# Epoch 42/100
# 1/1 [==============================] - 0s 73ms/step - loss: 3.9576e-05 - mean_absolute_error: 0.0049
# Epoch 43/100
# 1/1 [==============================] - 0s 90ms/step - loss: 3.0840e-05 - mean_absolute_error: 0.0041
# Epoch 44/100
# 1/1 [==============================] - 0s 76ms/step - loss: 2.6369e-05 - mean_absolute_error: 0.0040
# Epoch 45/100
# 1/1 [==============================] - 0s 70ms/step - loss: 3.1676e-05 - mean_absolute_error: 0.0043
# Epoch 46/100
# 1/1 [==============================] - 0s 75ms/step - loss: 2.0776e-05 - mean_absolute_error: 0.0037
# Epoch 47/100
# 1/1 [==============================] - 0s 76ms/step - loss: 2.4690e-05 - mean_absolute_error: 0.0042
# Epoch 48/100
# 1/1 [==============================] - 0s 92ms/step - loss: 4.0499e-05 - mean_absolute_error: 0.0055
# Epoch 49/100
# 1/1 [==============================] - 0s 91ms/step - loss: 3.4866e-05 - mean_absolute_error: 0.0049
# Epoch 50/100
# 1/1 [==============================] - 0s 90ms/step - loss: 5.6537e-05 - mean_absolute_error: 0.0065
# Epoch 51/100
# 1/1 [==============================] - 0s 76ms/step - loss: 7.3531e-05 - mean_absolute_error: 0.0072
# Epoch 52/100
# 1/1 [==============================] - 0s 78ms/step - loss: 1.1089e-04 - mean_absolute_error: 0.0098
# Epoch 53/100
# 1/1 [==============================] - 0s 78ms/step - loss: 1.7023e-04 - mean_absolute_error: 0.0117
# Epoch 54/100
# 1/1 [==============================] - 0s 71ms/step - loss: 1.8419e-04 - mean_absolute_error: 0.0124
# Epoch 55/100
# 1/1 [==============================] - 0s 76ms/step - loss: 7.0030e-05 - mean_absolute_error: 0.0076
# Epoch 56/100
# 1/1 [==============================] - 0s 70ms/step - loss: 4.0704e-05 - mean_absolute_error: 0.0053
# Epoch 57/100
# 1/1 [==============================] - 0s 72ms/step - loss: 2.9865e-05 - mean_absolute_error: 0.0048
# Epoch 58/100
# 1/1 [==============================] - 0s 74ms/step - loss: 4.7513e-05 - mean_absolute_error: 0.0058
# Epoch 59/100
# 1/1 [==============================] - 0s 73ms/step - loss: 4.4613e-05 - mean_absolute_error: 0.0057
# Epoch 60/100
# 1/1 [==============================] - 0s 78ms/step - loss: 3.9264e-05 - mean_absolute_error: 0.0055
# Epoch 61/100
# 1/1 [==============================] - 0s 72ms/step - loss: 4.8487e-05 - mean_absolute_error: 0.0060
# Epoch 62/100
# 1/1 [==============================] - 0s 73ms/step - loss: 6.3160e-05 - mean_absolute_error: 0.0071
# Epoch 63/100
# 1/1 [==============================] - 0s 72ms/step - loss: 5.1525e-05 - mean_absolute_error: 0.0062
# Epoch 64/100
# 1/1 [==============================] - 0s 77ms/step - loss: 4.4403e-05 - mean_absolute_error: 0.0059
# Epoch 65/100
# 1/1 [==============================] - 0s 76ms/step - loss: 6.2327e-05 - mean_absolute_error: 0.0069
# Epoch 66/100
# 1/1 [==============================] - 0s 73ms/step - loss: 6.5573e-05 - mean_absolute_error: 0.0073
# Epoch 67/100
# 1/1 [==============================] - 0s 89ms/step - loss: 4.7298e-05 - mean_absolute_error: 0.0056
# Epoch 68/100
# 1/1 [==============================] - 0s 75ms/step - loss: 2.7504e-05 - mean_absolute_error: 0.0041
# Epoch 69/100
# 1/1 [==============================] - 0s 75ms/step - loss: 3.0686e-05 - mean_absolute_error: 0.0043
# Epoch 70/100
# 1/1 [==============================] - 0s 70ms/step - loss: 5.2953e-05 - mean_absolute_error: 0.0063
# Epoch 71/100
# 1/1 [==============================] - 0s 78ms/step - loss: 8.1099e-05 - mean_absolute_error: 0.0073
# Epoch 72/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.0774e-04 - mean_absolute_error: 0.0098
# Epoch 73/100
# 1/1 [==============================] - 0s 86ms/step - loss: 1.4126e-04 - mean_absolute_error: 0.0103
# Epoch 74/100
# 1/1 [==============================] - 0s 107ms/step - loss: 1.1635e-04 - mean_absolute_error: 0.0102
# Epoch 75/100
# 1/1 [==============================] - 0s 90ms/step - loss: 6.0813e-05 - mean_absolute_error: 0.0066
# Epoch 76/100
# 1/1 [==============================] - 0s 94ms/step - loss: 2.4019e-05 - mean_absolute_error: 0.0039
# Epoch 77/100
# 1/1 [==============================] - 0s 152ms/step - loss: 1.7608e-05 - mean_absolute_error: 0.0036
# Epoch 78/100
# 1/1 [==============================] - 0s 83ms/step - loss: 2.6414e-05 - mean_absolute_error: 0.0040
# Epoch 79/100
# 1/1 [==============================] - 0s 78ms/step - loss: 3.2297e-05 - mean_absolute_error: 0.0043
# Epoch 80/100
# 1/1 [==============================] - 0s 83ms/step - loss: 1.4854e-05 - mean_absolute_error: 0.0031
# Epoch 81/100
# 1/1 [==============================] - 0s 74ms/step - loss: 1.6057e-05 - mean_absolute_error: 0.0033
# Epoch 82/100
# 1/1 [==============================] - 0s 91ms/step - loss: 1.9532e-05 - mean_absolute_error: 0.0034
# Epoch 83/100
# 1/1 [==============================] - 0s 139ms/step - loss: 3.9582e-05 - mean_absolute_error: 0.0053
# Epoch 84/100
# 1/1 [==============================] - 0s 99ms/step - loss: 6.5866e-05 - mean_absolute_error: 0.0075
# Epoch 85/100
# 1/1 [==============================] - 0s 102ms/step - loss: 9.8129e-05 - mean_absolute_error: 0.0086
# Epoch 86/100
# 1/1 [==============================] - 0s 100ms/step - loss: 9.2673e-05 - mean_absolute_error: 0.0090
# Epoch 87/100
# 1/1 [==============================] - 0s 90ms/step - loss: 1.1507e-04 - mean_absolute_error: 0.0095
# Epoch 88/100
# 1/1 [==============================] - 0s 101ms/step - loss: 9.8953e-05 - mean_absolute_error: 0.0091
# Epoch 89/100
# 1/1 [==============================] - 0s 102ms/step - loss: 6.4355e-05 - mean_absolute_error: 0.0069
# Epoch 90/100
# 1/1 [==============================] - 0s 104ms/step - loss: 3.4703e-05 - mean_absolute_error: 0.0051
# Epoch 91/100
# 1/1 [==============================] - 0s 85ms/step - loss: 1.9273e-05 - mean_absolute_error: 0.0037
# Epoch 92/100
# 1/1 [==============================] - 0s 87ms/step - loss: 3.2448e-05 - mean_absolute_error: 0.0050
# Epoch 93/100
# 1/1 [==============================] - 0s 98ms/step - loss: 4.0848e-05 - mean_absolute_error: 0.0056
# Epoch 94/100
# 1/1 [==============================] - 0s 83ms/step - loss: 3.4073e-05 - mean_absolute_error: 0.0044
# Epoch 95/100
# 1/1 [==============================] - 0s 85ms/step - loss: 3.0515e-05 - mean_absolute_error: 0.0049
# Epoch 96/100
# 1/1 [==============================] - 0s 98ms/step - loss: 4.0937e-05 - mean_absolute_error: 0.0051
# Epoch 97/100
# 1/1 [==============================] - 0s 87ms/step - loss: 2.7883e-05 - mean_absolute_error: 0.0043
# Epoch 98/100
# 1/1 [==============================] - 0s 83ms/step - loss: 5.0773e-05 - mean_absolute_error: 0.0061
# Epoch 99/100
# 1/1 [==============================] - 0s 100ms/step - loss: 1.1394e-04 - mean_absolute_error: 0.0098
# Epoch 100/100
# 1/1 [==============================] - 0s 86ms/step - loss: 1.4482e-04 - mean_absolute_error: 0.0114
#
#
#
# Counter = 2
#
#
#
# Num_batches = 2

# %%
# Preparing test data
base_teste = spark.read \
    .format("jdbc") \
    .option("url", mysql_url) \
    .option("dbtable", "stock_data") \
    .option("user", mysql_properties["user"]) \
    .option("password", mysql_properties["password"]) \
    .option("driver", mysql_properties["driver"]) \
    .load()

preco_real_teste = base_teste.select('Open').toPandas().iloc[:, 0].values

# %%
base_completa = pd.concat((base_treinamento['Open'], preco_real_teste), axis=0)
entradas = base_completa[len(base_completa) - len(preco_real_teste) - 90:].values
entradas = entradas.reshape(-1, 1)
entradas = normalizador.transform(entradas)

X_teste = []

for i in range(90, len(entradas)):
    X_teste.append(entradas[i-90:i, 0])

X_teste = np.array(X_teste)
X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 base_completa = pd.concat((base_treinamento['Open'], preco_real_teste), axis=0)
#       2 entradas = base_completa[len(base_completa) - len(preco_real_teste) - 90:].values
#       3 entradas = entradas.reshape(-1, 1)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py:446, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
# --> 446 ndims = self._get_ndims(objs)
#     447 sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     449 # Standardize axis parameter to int
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/concat.py:487, in _Concatenator._get_ndims(self, objs)
#     482     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     483         msg = (
#     484             f"cannot concatenate object of type '{type(obj)}'; "
#     485             "only Series and DataFrame objs are valid"
#     486         )
# --> 487         raise TypeError(msg)
#     489     ndims.add(obj.ndim)
#     490 return ndims
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %%
# Making predictions
previsoes = regressor.predict(X_teste)
previsoes = normalizador.inverse_transform(previsoes)

# Plotting the results
plt.plot(preco_real_teste, color='red', label='Preço real')
plt.plot(previsoes, color='blue', label='Previsões')
plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
plt.show()
